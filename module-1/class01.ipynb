# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(type("2"))
# Out:
# <class 'str'>

# %%
print(type(2))
# Out:
# <class 'int'>

# %%
print("Ayan Hussain")
# Out:
# Ayan Hussain

# %%
print("Ayan Hussain - 2")
print("Hello World! - 1")
# Out:
# Ayan Hussain - 2
# Hello World! - 1

# %%
# Variables -- A container that stores some value 
# data types

name = "waqas"  # string -- aplhabit value
print("My name is:",name) 

# shortcut --> shift + enter

# = assignment operator
# Out:
# My name is: waqas

# %%
age = 50        # int - whole numbers (0-infinite)
print(age)
print("My name is:", name, "My age is:", age)

# Homework -- what are the F-strings
# Out:
# 50
# My name is: waqas My age is: 50

# %%
height = 5.7  # float - decimal values
print(height)
# Out:
# 5.7

# %%
bool_value = True # boolean -- true or false 
print(bool_value)
# Out:
# True

# %%
# type -- to find data type 
print(type(name)) 
print(type(age)) 
print(type(height)) 
print(type(bool_value))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
planet_name = "Mars" # line 1

planet_name = "Earth" # over write 
print(planet_name)
print(planet_name)
# Out:
# Mars
# Earth

# %%
subject = "maths" # first assigned value 
print(subject)
# Out:
# maths

# %%
subject = "Programming" # second assigned value 
print(subject) #\n
# Out:
# Programming

# %%
print(subject)
# Out:
# maths

# %%
city_1 =  "Karachi"
city_2 =  "Lahore"

print(city_1,"\n",city_2) # line gap \n

# use of "end" to line gap in print statements
# Out:
# Karachi
#  Lahore

# %%
print(city_1, end = "    !")
# Out:
# Karachi    !

# %%
city_1 =  "Karachi"
city_2 =  "Lahore"

print(city_1,"\n",city_2, sep = ' ') # line gap \n
# Out:
# Karachi
# Lahore

# %%
first_name =  "Ayan"
last_name  =  "Hussain"

print(first_name +" "+ last_name) # concatenate
# Out:
# Ayan Hussain
